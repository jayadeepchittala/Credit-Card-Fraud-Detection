# %%
import os

print(os.getcwd())
# Out:
# C:\Users\JAYADEEP\Desktop\Credit_Card_Fraud_Detection\notebooks

# %%
import os

print(os.listdir(".."))
# Out:
# ['data', 'models', 'notebooks']

# %%
print(os.listdir("../data"))
# Out:
# ['.ipynb_checkpoints', 'creditcard.csv', 'Untitled.ipynb']
